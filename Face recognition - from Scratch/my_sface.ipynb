# %%
from tensorflow import keras as tfk
import tensorflow as tf

# %%
# SFace is Robust, becauae it uses a different loss function - Sigmoid Constrained Hypersphere Loss (SCH)

def sigmoid_constrained_hypersphere_loss(y_true, y_pred, alpha=1.0, m=1.0):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    # Compute the cosine similarity between the feature vectors and the weight vectors
    cosine_sim = tf.reduce_sum(y_true * y_pred, axis=-1)

    # Compute the predicted probabilities
    p = (1.0 + alpha * y_true * cosine_sim) / (1.0 + alpha)

    # Compute the loss
    loss = -tf.reduce_mean(tf.math.log(p + 1e-12))

    return loss

# %% [markdown]
# The SFace model uses the above loss function, on the MobileFacenet architecture ~

# %%
# MobileFaceNet Architecture ~
def conv_block(input, n_filters, kernel_size, stride=1, padding='same'):
    x = tfk.layers.Conv2D(n_filters, kernel_size, stride, padding)(input)
    x = tfk.layers.BatchNormalization(epsilon=0.001)(x)
    x = tfk.layers.PReLU()(x)
    return x

def depthwise_conv_block(input, n_filters, kernel_size, stride=1, padding = 'same'):
    x = tfk.layers.SeparableConv2D(n_filters, kernel_size, stride, padding)(input)
    x = tfk.layers.BatchNormalization(epsilon=0.001)(x)
    x = tfk.layers.PReLU()(x)
    return x

def inverted_residual_block(input, n_filters, stride, expf):
    channel_axis = 1 if tfk.backend.image_data_format() == 'channels_first' else -1
    n_input_channels = tfk.backend.int_shape(input)[channel_axis]
    x = input
    #Expansion
    x = tfk.layers.Conv2D(n_input_channels * expf, kernel_size=1, padding='same')(x)
    x = tfk.layers.BatchNormalization(epsilon=0.001)(x)
    x = tfk.layers.PReLU()(x)

    #Depthwise
    x = tfk.layers.DepthwiseConv2D(kernel_size=3, strides=stride, padding='same')(x)
    x = tfk.layers.BatchNormalization(epsilon=0.001)(x)
    x = tfk.layers.PReLU()(x)

    #Projection
    x = tfk.layers.Conv2D(n_filters, kernel_size=1, padding='same')(x)
    x = tfk.layers.BatchNormalization(epsilon=0.001)(x)

    #Skip connection
    if n_input_channels == n_filters and stride == 1:
        x = tfk.layers.Add()([input, x])
    
    return x

def bottleneck(input, n_filters, stride, expf, repeat=1):
    for i in range(repeat):
        input = inverted_residual_block(input, n_filters, stride, expf)
    return input

# MobileFaceNet Model ~
def My_mobilefacenet(input_shape=(112,112,3), n_classes=512):
    input = tfk.layers.Input(shape=input_shape)
    x = conv_block(input, n_filters=64, kernel_size=3, stride=2)

    x = depthwise_conv_block(x, n_filters=64, kernel_size=3, stride=1)

    x = bottleneck(x, n_filters=64, stride=2, expf=2, repeat=5)
    x = bottleneck(x, n_filters=128, stride=2, expf=4, repeat=1)
    x = bottleneck(x, n_filters=128, stride=1, expf=2, repeat=6)
    x = bottleneck(x, n_filters=128, stride=2, expf=4, repeat=1)
    x = bottleneck(x, n_filters=128, stride=1, expf=2, repeat=2)
    
    x = conv_block(x, n_filters=512, kernel_size=1, stride=1)

    x = tfk.layers.GlobalAveragePooling2D()(x)

    x = tf.keras.layers.Dense(128)(x)

    outputs = tfk.layers.Lambda(lambda x: tf.math.l2_normalize(x, axis=1))(x)

    model = tfk.models.Model(inputs=input, outputs=outputs)

    return model

model = My_mobilefacenet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 112, 112, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 56, 56, 64)   1792        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 56, 56, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  p_re_lu (PReLU)                (None, 56, 56, 64)   200704      ['batch_normalization[0][0]']
#
#  separable_conv2d (SeparableCon  (None, 56, 56, 64)  4736        ['p_re_lu[0][0]']
#  v2D)
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['separable_conv2d[0][0]']
#  rmalization)
#
#  p_re_lu_1 (PReLU)              (None, 56, 56, 64)   200704      ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 128)  8320        ['p_re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_1[0][0]']
#  rmalization)
#
#  p_re_lu_2 (PReLU)              (None, 56, 56, 128)  401408      ['batch_normalization_2[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 28, 28, 128)  1280       ['p_re_lu_2[0][0]']
#  v2D)
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 128)  512        ['depthwise_conv2d[0][0]']
#  rmalization)
#
#  p_re_lu_3 (PReLU)              (None, 28, 28, 128)  100352      ['batch_normalization_3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 64)   8256        ['p_re_lu_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 128)  8320        ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  p_re_lu_4 (PReLU)              (None, 28, 28, 128)  100352      ['batch_normalization_5[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 14, 14, 128)  1280       ['p_re_lu_4[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 128)  512        ['depthwise_conv2d_1[0][0]']
#  rmalization)
#
#  p_re_lu_5 (PReLU)              (None, 14, 14, 128)  25088       ['batch_normalization_6[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 14, 14, 64)   8256        ['p_re_lu_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 14, 14, 128)  8320        ['batch_normalization_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  p_re_lu_6 (PReLU)              (None, 14, 14, 128)  25088       ['batch_normalization_8[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 7, 7, 128)   1280        ['p_re_lu_6[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 128)   512         ['depthwise_conv2d_2[0][0]']
#  rmalization)
#
#  p_re_lu_7 (PReLU)              (None, 7, 7, 128)    6272        ['batch_normalization_9[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 7, 7, 64)     8256        ['p_re_lu_7[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 64)    256         ['conv2d_6[0][0]']
#  ormalization)
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 128)    8320        ['batch_normalization_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 128)   512         ['conv2d_7[0][0]']
#  ormalization)
#
#  p_re_lu_8 (PReLU)              (None, 7, 7, 128)    6272        ['batch_normalization_11[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 4, 4, 128)   1280        ['p_re_lu_8[0][0]']
#  onv2D)
#
#  batch_normalization_12 (BatchN  (None, 4, 4, 128)   512         ['depthwise_conv2d_3[0][0]']
#  ormalization)
#
#  p_re_lu_9 (PReLU)              (None, 4, 4, 128)    2048        ['batch_normalization_12[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 64)     8256        ['p_re_lu_9[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 4, 4, 64)    256         ['conv2d_8[0][0]']
#  ormalization)
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 128)    8320        ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 4, 4, 128)   512         ['conv2d_9[0][0]']
#  ormalization)
#
#  p_re_lu_10 (PReLU)             (None, 4, 4, 128)    2048        ['batch_normalization_14[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 2, 2, 128)   1280        ['p_re_lu_10[0][0]']
#  onv2D)
#
#  batch_normalization_15 (BatchN  (None, 2, 2, 128)   512         ['depthwise_conv2d_4[0][0]']
#  ormalization)
#
#  p_re_lu_11 (PReLU)             (None, 2, 2, 128)    512         ['batch_normalization_15[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 2, 2, 64)     8256        ['p_re_lu_11[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 2, 2, 64)    256         ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 2, 2, 256)    16640       ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_11[0][0]']
#  ormalization)
#
#  p_re_lu_12 (PReLU)             (None, 2, 2, 256)    1024        ['batch_normalization_17[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 1, 1, 256)   2560        ['p_re_lu_12[0][0]']
#  onv2D)
#
#  batch_normalization_18 (BatchN  (None, 1, 1, 256)   1024        ['depthwise_conv2d_5[0][0]']
#  ormalization)
#
#  p_re_lu_13 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_18[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 1, 1, 128)    32896       ['p_re_lu_13[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 1, 1, 128)   512         ['conv2d_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 1, 1, 256)    33024       ['batch_normalization_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_13[0][0]']
#  ormalization)
#
#  p_re_lu_14 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_20[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 1, 1, 256)   2560        ['p_re_lu_14[0][0]']
#  onv2D)
#
#  batch_normalization_21 (BatchN  (None, 1, 1, 256)   1024        ['depthwise_conv2d_6[0][0]']
#  ormalization)
#
#  p_re_lu_15 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_21[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 1, 1, 128)    32896       ['p_re_lu_15[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 1, 1, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  add (Add)                      (None, 1, 1, 128)    0           ['batch_normalization_19[0][0]',
#                                                                   'batch_normalization_22[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 1, 1, 256)    33024       ['add[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_15[0][0]']
#  ormalization)
#
#  p_re_lu_16 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_23[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 1, 1, 256)   2560        ['p_re_lu_16[0][0]']
#  onv2D)
#
#  batch_normalization_24 (BatchN  (None, 1, 1, 256)   1024        ['depthwise_conv2d_7[0][0]']
#  ormalization)
#
#  p_re_lu_17 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_24[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 1, 1, 128)    32896       ['p_re_lu_17[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 1, 1, 128)   512         ['conv2d_16[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 1, 1, 128)    0           ['add[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 1, 1, 256)    33024       ['add_1[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_17[0][0]']
#  ormalization)
#
#  p_re_lu_18 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_26[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 1, 1, 256)   2560        ['p_re_lu_18[0][0]']
#  onv2D)
#
#  batch_normalization_27 (BatchN  (None, 1, 1, 256)   1024        ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  p_re_lu_19 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_27[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 1, 1, 128)    32896       ['p_re_lu_19[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 1, 1, 128)   512         ['conv2d_18[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 1, 1, 128)    0           ['add_1[0][0]',
#                                                                   'batch_normalization_28[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 1, 1, 256)    33024       ['add_2[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  p_re_lu_20 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_29[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 1, 1, 256)   2560        ['p_re_lu_20[0][0]']
#  onv2D)
#
#  batch_normalization_30 (BatchN  (None, 1, 1, 256)   1024        ['depthwise_conv2d_9[0][0]']
#  ormalization)
#
#  p_re_lu_21 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_30[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 1, 1, 128)    32896       ['p_re_lu_21[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 1, 1, 128)   512         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 1, 1, 128)    0           ['add_2[0][0]',
#                                                                   'batch_normalization_31[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 1, 1, 256)    33024       ['add_3[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  p_re_lu_22 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_32[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (None, 1, 1, 256)   2560        ['p_re_lu_22[0][0]']
#  Conv2D)
#
#  batch_normalization_33 (BatchN  (None, 1, 1, 256)   1024        ['depthwise_conv2d_10[0][0]']
#  ormalization)
#
#  p_re_lu_23 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_33[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 1, 1, 128)    32896       ['p_re_lu_23[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 1, 1, 128)   512         ['conv2d_22[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 1, 1, 128)    0           ['add_3[0][0]',
#                                                                   'batch_normalization_34[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 1, 1, 256)    33024       ['add_4[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  p_re_lu_24 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_35[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 1, 1, 256)   2560        ['p_re_lu_24[0][0]']
#  Conv2D)
#
#  batch_normalization_36 (BatchN  (None, 1, 1, 256)   1024        ['depthwise_conv2d_11[0][0]']
#  ormalization)
#
#  p_re_lu_25 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_36[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 1, 1, 128)    32896       ['p_re_lu_25[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 1, 1, 128)   512         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 1, 1, 128)    0           ['add_4[0][0]',
#                                                                   'batch_normalization_37[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 1, 1, 512)    66048       ['add_5[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_25[0][0]']
#  ormalization)
#
#  p_re_lu_26 (PReLU)             (None, 1, 1, 512)    512         ['batch_normalization_38[0][0]']
#
#  depthwise_conv2d_12 (Depthwise  (None, 1, 1, 512)   5120        ['p_re_lu_26[0][0]']
#  Conv2D)
#
#  batch_normalization_39 (BatchN  (None, 1, 1, 512)   2048        ['depthwise_conv2d_12[0][0]']
#  ormalization)
#
#  p_re_lu_27 (PReLU)             (None, 1, 1, 512)    512         ['batch_normalization_39[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 1, 1, 128)    65664       ['p_re_lu_27[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 1, 1, 128)   512         ['conv2d_26[0][0]']
#  ormalization)
#
#  conv2d_27 (Conv2D)             (None, 1, 1, 256)    33024       ['batch_normalization_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  p_re_lu_28 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_41[0][0]']
#
#  depthwise_conv2d_13 (Depthwise  (None, 1, 1, 256)   2560        ['p_re_lu_28[0][0]']
#  Conv2D)
#
#  batch_normalization_42 (BatchN  (None, 1, 1, 256)   1024        ['depthwise_conv2d_13[0][0]']
#  ormalization)
#
#  p_re_lu_29 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_42[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 1, 1, 128)    32896       ['p_re_lu_29[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 1, 1, 128)   512         ['conv2d_28[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 1, 1, 128)    0           ['batch_normalization_40[0][0]',
#                                                                   'batch_normalization_43[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 1, 1, 256)    33024       ['add_6[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  p_re_lu_30 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_44[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (None, 1, 1, 256)   2560        ['p_re_lu_30[0][0]']
#  Conv2D)
#
#  batch_normalization_45 (BatchN  (None, 1, 1, 256)   1024        ['depthwise_conv2d_14[0][0]']
#  ormalization)
#
#  p_re_lu_31 (PReLU)             (None, 1, 1, 256)    256         ['batch_normalization_45[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 1, 1, 128)    32896       ['p_re_lu_31[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 1, 1, 128)   512         ['conv2d_30[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 1, 1, 128)    0           ['add_6[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 1, 1, 512)    66048       ['add_7[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_31[0][0]']
#  ormalization)
#
#  p_re_lu_32 (PReLU)             (None, 1, 1, 512)    512         ['batch_normalization_47[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['p_re_lu_32[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 128)          65664       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  lambda (Lambda)                (None, 128)          0           ['dense[0][0]']
#
# ==================================================================================================
# Total params: 2,078,656
# Trainable params: 2,060,352
# Non-trainable params: 18,304
# __________________________________________________________________________________________________

# %%
# Get & Load datasets ~
train_data, test_data = [], []

# %%
model.compile(optimizer=tfk.optimizers.Adam(learning_rate=0.001),
                loss = sigmoid_constrained_hypersphere_loss,
                metrics=['accuracy'])

# %%
history = model.fit(train_data,
                        epochs = 10,
                        steps_per_epoch = len(train_data),
                        validation_data = test_data,
                        validation_steps = len(test_data),
                        verbose = 1)
